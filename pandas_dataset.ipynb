# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Dataset.txt')
df
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
sns.jointplot(x=input("Enter the column name for x-axis (e.g., 'Length of Membership'):"), y='Yearly Amount Spent', data=df, alpha=0.8);
# Out:
# Enter the column name for x-axis (e.g., 'Length of Membership'):Length of Membership

# %%
df.colums = df.columns.str.strip()
# Out:
# /tmp/ipython-input-1746836854.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.colums = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
sns.pairplot(df, kind='scatter',plot_kws={'alpha':0.5});

# %%
sns.lmplot(
           x='Length of Membership',
           y='Yearly Amount Spent', data=df,
           scatter_kws={'alpha':0.5},
           line_kws={'color': 'red'},
           ci=95
           )

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
x = df[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]
y = df[['Yearly Amount Spent']]

# %%
x.shape
# Out:
# (500, 4)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([[25.72425621, 38.59713548,  0.45914788, 61.67473243]])

# %%
prediction = lm.predict(x_test)

# %%
x_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 361            32.077590    10.347877        39.045156              3.434560
# 73             32.808698    12.817113        37.031539              3.851579
# 374            31.447446    10.101632        38.043453              4.238296
# 155            32.449522    13.457725        37.238806              2.941411
# 104            31.389585    10.994224        38.074452              3.428860
# ..                   ...          ...              ...                   ...
# 266            34.555283    11.777772        37.979827              3.784273
# 23             32.903251    11.657576        36.772604              3.919302
# 222            34.334865    11.109456        38.585855              3.892891
# 261            32.550527    13.041245        36.655208              3.456234
# 426            31.425227    13.271475        37.239847              4.022103
#
# [150 rows x 4 columns]

# %%
y_test
# Out:
#      Yearly Amount Spent
# 361           401.033135
# 73            534.777188
# 374           418.602742
# 155           503.978379
# 104           410.069611
# ..                   ...
# 266           554.003093
# 23            519.340989
# 222           502.409785
# 261           514.009818
# 426           530.766719
#
# [150 rows x 1 columns]

# %%
prediction
# Out:
# array([[403.66993069],
#        [542.57756289],
#        [427.06591658],
#        [502.02460425],
#        [410.12143559],
#        [569.93442508],
#        [531.93431341],
#        [506.29650969],
#        [408.71870658],
#        [473.97737105],
#        [441.46912726],
#        [425.33703059],
#        [425.1297229 ],
#        [527.61676714],
#        [431.45684016],
#        [424.0769184 ],
#        [575.76543296],
#        [484.89856554],
#        [458.35936863],
#        [481.96502182],
#        [502.32441491],
#        [513.63783554],
#        [507.58877002],
#        [646.57464283],
#        [450.24372141],
#        [496.27043415],
#        [556.40457807],
#        [554.95630839],
#        [399.64237199],
#        [325.84623136],
#        [532.89783259],
#        [478.12238702],
#        [501.05701845],
#        [305.97335848],
#        [505.77244448],
#        [483.79591969],
#        [518.8331528 ],
#        [438.18241857],
#        [456.71094234],
#        [471.04609461],
# ...

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x=y_test.values.flatten(), y=prediction.flatten(), color = 'red', label='prediction')
sns.scatterplot(x=y_test.values.flatten(), y=y_test.values.flatten(), color = 'blue', label='Actual')
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.title('Actual vs Prediction')
plt.legend()
plt.show()
